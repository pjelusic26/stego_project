# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('five_frequencies_0_ssim.csv')
df.drop(['Unnamed: 0'], axis = 1, inplace = True)
df.columns = ([
    'alpha', 
    'L Marked', 'L Masked', 
    'LM Marked', 'LM Masked',
    'M Marked', 'M Masked',
    'MH Marked', 'MH Masked',
    'H Marked', 'H Masked',
])

# %%
df[::5]
# Out:
#     alpha  L Marked  L Masked  LM Marked  LM Masked  M Marked  M Masked  \
# 0     0.0  1.000000  0.999378   1.000000   0.999378  1.000000  0.999378
# 5     2.5  0.997314  0.999393   0.997867   0.999394  0.999186  0.999390
# 10    5.0  0.991368  0.999384   0.992877   0.999390  0.997090  0.999394
# 15    7.5  0.984268  0.999376   0.986474   0.999382  0.994071  0.999392
# 20   10.0  0.977220  0.999371   0.979530   0.999377  0.990424  0.999388
# 25   12.5  0.970616  0.999368   0.972552   0.999373  0.986371  0.999384
# 30   15.0  0.964440  0.999366   0.965905   0.999369  0.982078  0.999381
# 35   17.5  0.958926  0.999364   0.959694   0.999368  0.977629  0.999377
# 40   20.0  0.954112  0.999363   0.953940   0.999366  0.973201  0.999374
# 45   22.5  0.949921  0.999362   0.948633   0.999365  0.968915  0.999371
# 50   25.0  0.946263  0.999361   0.943753   0.999364  0.964823  0.999369
# 55   27.5  0.943071  0.999361   0.939271   0.999363  0.960930  0.999367
# ...

# %%
df.shape
# Out:
# (61, 11)

# %%
df.plot(x = 'alpha', y = ['L Marked', 'LM Marked', 'M Marked', 'MH Marked', 'H Marked', 'L Masked'], figsize = (16, 9), lw = 5, fontsize = 16)
# Out:
# <AxesSubplot:xlabel='alpha'>
